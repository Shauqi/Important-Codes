# %%
# !pip install tensorboardcolab
# Out:
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)

# %%
from tensorboardcolab import TensorBoardColab, TensorBoardColabCallback

tbc=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://edf38ff1.ngrok.io

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.reshape(60000, 784).astype('float32') / 255
x_test = x_test.reshape(10000, 784).astype('float32') / 255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
digits = 10
y_train = tf.keras.utils.to_categorical(y_train, digits)
y_test = tf.keras.utils.to_categorical(y_test, digits)

# %%
import tensorflow as tf

# %%
import keras 
from keras.layers import Dense 
from keras.models import Sequential
from keras import optimizers

# %%
model = Sequential()

# first hidden layer
model.add(Dense(output_dim = 400, init = 'uniform', activation = 'relu', input_dim = 784))

# second hidden layer
model.add(Dense(output_dim = 300, init = 'uniform', activation = 'relu'))

# third hidden layer
model.add(Dense(output_dim = 300, init = 'uniform', activation = 'relu'))

# fourth hidden layer
model.add(Dense(output_dim = 300, init = 'uniform', activation = 'relu'))

# fifth hidden layer
model.add(Dense(output_dim = 100, init = 'uniform', activation = 'relu'))

# output layer
# output_dim = no. of digits
# softmax activation function is used for multiple outputs
model.add(Dense(output_dim = 10, init = 'uniform', activation = 'softmax'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=784, units=400, kernel_initializer="uniform")`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=300, kernel_initializer="uniform")`
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=300, kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=300, kernel_initializer="uniform")`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=100, kernel_initializer="uniform")`
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="softmax", units=10, kernel_initializer="uniform")`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 400)               314000
# _________________________________________________________________
# dense_2 (Dense)              (None, 300)               120300
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dense_4 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 646,010
# Trainable params: 646,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
learning_rate = 0.01
sgd = optimizers.SGD(lr = learning_rate)


# compiling the model
# using the plain vanilla stochastic gradient descent as our optimizing technique
# using categorical cross entropy for multiple outputs
model.compile(optimizer = 'sgd', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# feeding the training data to the model
model.fit(x_train, y_train, batch_size = 100, epochs = 60, verbose = 2, validation_data = (x_test, y_test), callbacks=[TensorBoardColabCallback(tbc)])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/60
#  - 3s - loss: 2.3018 - acc: 0.1116 - val_loss: 2.3011 - val_acc: 0.1135
# Epoch 2/60
#  - 2s - loss: 2.3008 - acc: 0.1124 - val_loss: 2.3003 - val_acc: 0.1135
# Epoch 3/60
#  - 2s - loss: 2.3002 - acc: 0.1124 - val_loss: 2.2997 - val_acc: 0.1135
# Epoch 4/60
#  - 2s - loss: 2.2995 - acc: 0.1124 - val_loss: 2.2988 - val_acc: 0.1135
# Epoch 5/60
#  - 2s - loss: 2.2985 - acc: 0.1124 - val_loss: 2.2975 - val_acc: 0.1135
# Epoch 6/60
#  - 2s - loss: 2.2967 - acc: 0.1124 - val_loss: 2.2950 - val_acc: 0.1135
# Epoch 7/60
#  - 2s - loss: 2.2929 - acc: 0.1124 - val_loss: 2.2891 - val_acc: 0.1135
# Epoch 8/60
#  - 2s - loss: 2.2818 - acc: 0.1257 - val_loss: 2.2679 - val_acc: 0.1827
# Epoch 9/60
#  - 2s - loss: 2.1953 - acc: 0.2572 - val_loss: 1.9904 - val_acc: 0.3174
# Epoch 10/60
#  - 2s - loss: 1.4270 - acc: 0.4953 - val_loss: 1.0292 - val_acc: 0.6339
# Epoch 11/60
#  - 2s - loss: 0.9436 - acc: 0.6723 - val_loss: 0.8543 - val_acc: 0.7051
# Epoch 12/60
#  - 2s - loss: 0.7694 - acc: 0.7567 - val_loss: 0.6618 - val_acc: 0.8114
# Epoch 13/60
#  - 2s - loss: 0.5365 - acc: 0.8474 - val_loss: 0.4570 - val_acc: 0.8749
# Epoch 14/60
#  - 2s - loss: 0.4266 - acc: 0.8800 - val_loss: 0.3767 - val_acc: 0.8947
# Epoch 15/60
#  - 2s - loss: 0.3662 - acc: 0.8977 - val_loss: 0.3403 - val_acc: 0.9075
# Epoch 16/60
#  - 2s - loss: 0.3186 - acc: 0.9125 - val_loss: 0.3183 - val_acc: 0.9130
# Epoch 17/60
#  - 2s - loss: 0.2813 - acc: 0.9230 - val_loss: 0.2692 - val_acc: 0.9285
# Epoch 18/60
#  - 2s - loss: 0.2500 - acc: 0.9316 - val_loss: 0.2696 - val_acc: 0.9295
# Epoch 19/60
#  - 2s - loss: 0.2239 - acc: 0.9399 - val_loss: 0.2306 - val_acc: 0.9381
# Epoch 20/60
#  - 2s - loss: 0.2009 - acc: 0.9458 - val_loss: 0.2126 - val_acc: 0.9429
# Epoch 21/60
#  - 2s - loss: 0.1818 - acc: 0.9512 - val_loss: 0.2044 - val_acc: 0.9457
# Epoch 22/60
#  - 2s - loss: 0.1647 - acc: 0.9557 - val_loss: 0.1923 - val_acc: 0.9477
# Epoch 23/60
#  - 2s - loss: 0.1485 - acc: 0.9594 - val_loss: 0.1796 - val_acc: 0.9506
# Epoch 24/60
#  - 2s - loss: 0.1349 - acc: 0.9636 - val_loss: 0.1879 - val_acc: 0.9508
# Epoch 25/60
#  - 2s - loss: 0.1232 - acc: 0.9669 - val_loss: 0.1731 - val_acc: 0.9522
# Epoch 26/60
#  - 2s - loss: 0.1131 - acc: 0.9698 - val_loss: 0.1560 - val_acc: 0.9590
# Epoch 27/60
#  - 2s - loss: 0.1047 - acc: 0.9713 - val_loss: 0.1526 - val_acc: 0.9594
# Epoch 28/60
#  - 2s - loss: 0.0964 - acc: 0.9736 - val_loss: 0.1453 - val_acc: 0.9617
# Epoch 29/60
#  - 2s - loss: 0.0879 - acc: 0.9760 - val_loss: 0.1552 - val_acc: 0.9592
# Epoch 30/60
#  - 2s - loss: 0.0808 - acc: 0.9782 - val_loss: 0.1431 - val_acc: 0.9629
# Epoch 31/60
#  - 2s - loss: 0.0748 - acc: 0.9795 - val_loss: 0.1552 - val_acc: 0.9587
# Epoch 32/60
#  - 2s - loss: 0.0695 - acc: 0.9815 - val_loss: 0.1606 - val_acc: 0.9591
# Epoch 33/60
#  - 2s - loss: 0.0638 - acc: 0.9822 - val_loss: 0.1393 - val_acc: 0.9641
# Epoch 34/60
#  - 2s - loss: 0.0583 - acc: 0.9841 - val_loss: 0.1420 - val_acc: 0.9627
# Epoch 35/60
#  - 2s - loss: 0.0532 - acc: 0.9860 - val_loss: 0.1422 - val_acc: 0.9634
# Epoch 36/60
#  - 2s - loss: 0.0490 - acc: 0.9867 - val_loss: 0.1407 - val_acc: 0.9645
# Epoch 37/60
#  - 2s - loss: 0.0445 - acc: 0.9883 - val_loss: 0.1403 - val_acc: 0.9645
# Epoch 38/60
#  - 2s - loss: 0.0404 - acc: 0.9894 - val_loss: 0.1452 - val_acc: 0.9649
# Epoch 39/60
#  - 2s - loss: 0.0375 - acc: 0.9902 - val_loss: 0.1470 - val_acc: 0.9660
# Epoch 40/60
#  - 2s - loss: 0.0333 - acc: 0.9916 - val_loss: 0.1516 - val_acc: 0.9634
# Epoch 41/60
#  - 2s - loss: 0.0312 - acc: 0.9922 - val_loss: 0.1715 - val_acc: 0.9575
# Epoch 42/60
#  - 2s - loss: 0.0287 - acc: 0.9931 - val_loss: 0.2069 - val_acc: 0.9475
# Epoch 43/60
#  - 2s - loss: 0.0244 - acc: 0.9944 - val_loss: 0.1471 - val_acc: 0.9666
# Epoch 44/60
#  - 2s - loss: 0.0224 - acc: 0.9950 - val_loss: 0.1454 - val_acc: 0.9667
# Epoch 45/60
#  - 2s - loss: 0.0204 - acc: 0.9950 - val_loss: 0.1575 - val_acc: 0.9681
# Epoch 46/60
#  - 2s - loss: 0.0175 - acc: 0.9963 - val_loss: 0.1538 - val_acc: 0.9662
# Epoch 47/60
#  - 2s - loss: 0.0151 - acc: 0.9971 - val_loss: 0.1656 - val_acc: 0.9625
# Epoch 48/60
#  - 2s - loss: 0.0134 - acc: 0.9976 - val_loss: 0.1610 - val_acc: 0.9649
# Epoch 49/60
#  - 2s - loss: 0.0135 - acc: 0.9971 - val_loss: 0.1556 - val_acc: 0.9673
# Epoch 50/60
#  - 2s - loss: 0.0116 - acc: 0.9980 - val_loss: 0.1576 - val_acc: 0.9661
# Epoch 51/60
#  - 2s - loss: 0.0093 - acc: 0.9989 - val_loss: 0.1592 - val_acc: 0.9665
# Epoch 52/60
#  - 2s - loss: 0.0088 - acc: 0.9987 - val_loss: 0.1634 - val_acc: 0.9662
# Epoch 53/60
#  - 2s - loss: 0.0905 - acc: 0.9872 - val_loss: 0.1561 - val_acc: 0.9666
# Epoch 54/60
#  - 2s - loss: 0.0119 - acc: 0.9977 - val_loss: 0.1547 - val_acc: 0.9678
# Epoch 55/60
#  - 2s - loss: 0.0070 - acc: 0.9995 - val_loss: 0.1560 - val_acc: 0.9681
# Epoch 56/60
#  - 2s - loss: 0.0059 - acc: 0.9996 - val_loss: 0.1596 - val_acc: 0.9689
# Epoch 57/60
#  - 2s - loss: 0.0052 - acc: 0.9997 - val_loss: 0.1603 - val_acc: 0.9686
# Epoch 58/60
#  - 2s - loss: 0.0046 - acc: 0.9998 - val_loss: 0.1614 - val_acc: 0.9692
# Epoch 59/60
#  - 2s - loss: 0.0043 - acc: 0.9998 - val_loss: 0.1641 - val_acc: 0.9693
# Epoch 60/60
#  - 2s - loss: 0.0038 - acc: 0.9998 - val_loss: 0.1673 - val_acc: 0.9691
